# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("mtcars.csv")
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
x=df[['cyl','disp','hp']].values
y=df['mpg'].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=44)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([16.03716916, 16.50265365, 25.80799579, 26.68866479, 21.61189623,
#        12.72783853, 16.50265365, 16.30880951, 26.85372479, 25.14802678])

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.94436693566282
# Mean Squared Error: 7.429406974291514
# Root Mean Squared Error: 2.7256938519011107

# %%
b0 = model.intercept_
b1 = model.coef_
r2 = r2_score(y_test, y_pred)
print("Intercept (b0):", b0)
print("Coefficients (b1):", b1)
print(f'R-squared (R²): {r2}')
# Out:
# Intercept (b0): 34.02370901524402
# Coefficients (b1): [-1.25622971 -0.01940288 -0.01177724]
# R-squared (R²): 0.7881935724791737

# %%
rdf = pd.DataFrame({'actual':y_test,'predicted':y_pred})
print(rdf.head())
# Out:
#    actual  predicted
# 0    15.5  16.037169
# 1    16.4  16.502654
# 2    22.8  25.807996
# 3    27.3  26.688665
# 4    19.7  21.611896

# %%
plt.scatter(df['hp'],y,color="skyblue",label="mlr on mtcars")
plt.plot(x_test,y_pred,color="red",linewidth=2)
plt.xlabel('HorsePower')
plt.ylabel('Mileage(mpg)')
plt.show()

# %%
df = pd.read_csv('abalone.csv')
x=df[['Length','Height']].values
y=df['Rings'].values

poly = PolynomialFeatures(degree=2)
x_poly=poly.fit_transform(x)
model = LinearRegression()
model.fit(x_poly,y)

y_pred = model.predict(x_poly)
rdf = pd.DataFrame({'actual':y,'predicted':y_pred})
print(rdf)

plt.scatter(df['Length'],y,color="skyblue",label="mlr on mtcars")
plt.xlabel('Length')
plt.ylabel('Rings')
plt.show()
plt.scatter(df['Height'],y,color="skyblue",label="mlr on mtcars")
plt.xlabel('Heigth')
plt.ylabel('Rings')
plt.show()
# Out:
#       actual  predicted
# 0         15   7.884855
# 1          7   7.352864
# 2          9   9.982771
# 3         10   9.431048
# 4          7   6.715294
# ...      ...        ...
# 4172      11  11.351014
# 4173      10   9.952646
# 4174       9  12.971851
# 4175      10  10.597299
# 4176      12  12.250524
#
# [4177 rows x 2 columns]
