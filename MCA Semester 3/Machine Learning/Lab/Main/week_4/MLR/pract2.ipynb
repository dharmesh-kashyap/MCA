# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv('room.csv')

x = df[['size', 'no. of bedrooms', 'number of floors', 'Age of homes']]
y = df['price']
# x=df[['cyl','disp','hp']].values
# y=df['mpg'].values

model = LinearRegression()

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
rdf = pd.DataFrame({'actual':y_test,'predicted':y_pred})
print(rdf)

print('Mean Absolute Error:', metrics.mean_absolute_error(y_train, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_train, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_train, y_pred)))

plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue', label='Predicted vs Actual')
plt.plot([min(y_test),max(y_test)], [min(y_pred),max(y_pred)], color='red', label='Ideal fit line')
plt.xlabel('Actual MPG')
plt.ylabel('Predicted MPG')
plt.title('Actual vs Predicted MPG')
plt.legend()
plt.show()
# Out:
#    actual   predicted
# 2     315   97.899673
# 3     178 -335.235055
# Mean Absolute Error: 435.067364282787
# Mean Squared Error: 319004.37701380183
# Root Mean Squared Error: 564.80472467376

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("C:/Users/mca/Desktop/saple.csv")

# %%
df
# Out:
#    Hours studies  Grade
# 0              2     69
# 1              9     98
# 2              5     82
# 3              5     77
# 4              3     71
# 5              7     84
# 6              1     55
# 7              8     94
# 8              6     84
# 9              2     64

# %%
X = df[['Hours studies']].values 
y = df['Grade'].values

# %%
X = np.c_[np.ones(X.shape[0]), X]

# %%
X_transpose = np.transpose(X)
X_transpose_X = np.matmul(X_transpose, X)

# %%
X_transpose_X_inv = np.linalg.inv(X_transpose_X)

# %%
X_transpose_y = np.matmul(X_transpose, y)

# %%
coeffs = np.matmul(X_transpose_X_inv, X_transpose_y)

# %%
print(f'Coefficients: {coeffs}')
# Out:
# Coefficients: [55.03550296  4.74260355]

# %%
y_pred = np.matmul(X, coeffs)
print(y_pred)
# Out:
# [64.52071006 97.71893491 78.74852071 78.74852071 69.26331361 88.23372781
#  59.77810651 92.97633136 83.49112426 64.52071006]
