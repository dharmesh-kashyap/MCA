# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn

# %%
df = pd.read_csv(r"D:\240970058\OneDrive - Manipal Academy of Higher Education\Desktop\MLDATASETS-19AUG2024\diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = df.drop('Outcome', axis=1)
y = df.Outcome

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
pca = PCA(n_components=2)

principal_comps = pca.fit_transform(X_scaled)
principal_df = pd.DataFrame(principal_comps, columns=['PC 1','PC 2'])
principal_df
# Out:
#          PC 1      PC 2
# 0    1.068503  1.234895
# 1   -1.121683 -0.733852
# 2   -0.396477  1.595876
# 3   -1.115781 -1.271241
# 4    2.359334 -2.184819
# ..        ...       ...
# 763  1.562085  1.923150
# 764 -0.100405 -0.614181
# 765 -0.283475  0.097065
# 766 -1.060324  0.837062
# 767 -0.839892 -1.151755
#
# [768 rows x 2 columns]

# %%
class_names = ['Outcome: 0','Outcome: 1']
for i, class_name in enumerate(class_names):
    plt.scatter(principal_comps[y == i, 0], principal_comps[y == i, 1], label=class_name)
plt.legend()
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Visualization')
# Out:
# Text(0.5, 1.0, 'PCA Visualization')

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.26179749 0.21640127]

# %%
import csv
with open('pca_diabetes_results.csv','w',newline='') as file:
    csvWriter = csv.writer(file)
    csvWriter.writerow(principal_df.columns.tolist())
    csvWriter.writerows(principal_df.values)
