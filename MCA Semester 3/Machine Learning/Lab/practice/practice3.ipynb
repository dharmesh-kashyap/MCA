# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import *

# %%
df = pd.read_csv("../DataSets/Salaries.csv")
df
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0             1      Prof          B             19           18  Male  139750
# 1             2      Prof          B             20           16  Male  173200
# 2             3  AsstProf          B              4            3  Male   79750
# 3             4      Prof          B             45           39  Male  115000
# 4             5      Prof          B             40           41  Male  141500
# ..          ...       ...        ...            ...          ...   ...     ...
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035
#
# [397 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# rank             0
# discipline       0
# yrs.since.phd    0
# yrs.service      0
# sex              0
# salary           0
# dtype: int64

# %%
df.dropna()
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0             1      Prof          B             19           18  Male  139750
# 1             2      Prof          B             20           16  Male  173200
# 2             3  AsstProf          B              4            3  Male   79750
# 3             4      Prof          B             45           39  Male  115000
# 4             5      Prof          B             40           41  Male  141500
# ..          ...       ...        ...            ...          ...   ...     ...
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035
#
# [397 rows x 7 columns]

# %%
#cat to num
df_encoded = pd.get_dummies(df, drop_first=True)

# %%
df_encoded.head()
# Out:
#    Unnamed: 0  yrs.since.phd  yrs.service  salary  rank_AsstProf  rank_Prof  \
# 0           1             19           18  139750          False       True
# 1           2             20           16  173200          False       True
# 2           3              4            3   79750           True      False
# 3           4             45           39  115000          False       True
# 4           5             40           41  141500          False       True
#
#    discipline_B  sex_Male
# 0          True      True
# 1          True      True
# 2          True      True
# 3          True      True
# 4          True      True

# %%
df_encoded = df_encoded.drop(columns=["Unnamed: 0"])

# %%
X=df_encoded.drop(columns=["salary"])

# %%
y=df_encoded["salary"]

# %%
X
# Out:
#      yrs.since.phd  yrs.service  rank_AsstProf  rank_Prof  discipline_B  \
# 0               19           18          False       True          True
# 1               20           16          False       True          True
# 2                4            3           True      False          True
# 3               45           39          False       True          True
# 4               40           41          False       True          True
# ..             ...          ...            ...        ...           ...
# 392             33           30          False       True         False
# 393             31           19          False       True         False
# 394             42           25          False       True         False
# 395             25           15          False       True         False
# 396              8            4           True      False         False
#
#      sex_Male
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 392      True
# 393      True
# 394      True
# 395      True
# 396      True
#
# [397 rows x 6 columns]

# %%
y.head()
# Out:
# 0    139750
# 1    173200
# 2     79750
# 3    115000
# 4    141500
# Name: salary, dtype: int64

# %%
test_sizes= [0.3, 0.4, 0.5]
model=LinearRegression()
for i in test_sizes: 
    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= i,random_state=42)
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    


    mse=mean_squared_error(y_test,y_pred)
    print(mse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 7
#       5 model.fit(X_train,y_train)
#       6 y_pred=model.predict(X_test)
# ----> 7 ac=accuracy_score(X,y)
#      10 mse=mean_squared_error(y_test,y_pred)
#      11 print(mse)
#
# File c:\Users\dharm\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\dharm\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:231, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     229 xp, _, device = get_namespace_and_device(y_true, y_pred, sample_weight)
#     230 # Compute accuracy for each possible representation
# --> 231 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     232 check_consistent_length(y_true, y_pred, sample_weight)
#     233 if y_type.startswith("multilabel"):
#
# File c:\Users\dharm\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:112, in _check_targets(y_true, y_pred)
#     109     y_type = {"multiclass"}
#     111 if len(y_type) > 1:
# --> 112     raise ValueError(
#     113         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#     114             type_true, type_pred
#     115         )
#     116     )
#     118 # We can't have more than one value on y_type => The set is no more needed
#     119 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of multiclass-multioutput and multiclass targets

# %%
input = [[31, 28, False, True, False, True]]
pred = model.predict(input)
print("prediction",pred)
# Out:
# prediction [120014.61470927]
# c:\Users\dharm\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
X_test
# Out:
#      yrs.since.phd  yrs.service  rank_AsstProf  rank_Prof  discipline_B  \
# 114             12            0          False       True         False
# 278             24           18          False       True         False
# 237              7            6           True      False         False
# 57               9            8          False      False          True
# 72              29           19          False       True          True
# ..             ...          ...            ...        ...           ...
# 198             34           33          False       True          True
# 377              6            3           True      False         False
# 307             31           28          False       True         False
# 183             26           22          False       True          True
# 292             39            9          False       True         False
#
#      sex_Male
# 114     False
# 278      True
# 237     False
