# %%
from sklearn.datasets import load_wine
import pandas as pd

# Load the Wine dataset from sklearn
wine = load_wine()

# Convert to a DataFrame
wine_df = pd.DataFrame(wine.data, columns=wine.feature_names)
wine_df['target'] = wine.target

# Explore the dataset
print("Purpose of the dataset: Classification of wine samples based on various chemical properties.")
print(f"Dimensions of the dataset: {wine_df.shape}")
print(f"Column Names and Data Types:\n{wine_df.dtypes}")
# Out:
# Purpose of the dataset: Classification of wine samples based on various chemical properties.
# Dimensions of the dataset: (178, 14)
# Column Names and Data Types:
# alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                             float64
# od280/od315_of_diluted_wines    float64
# proline                         float64
# target                            int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
import xlsxwriter

# Set up parameters
k_values = [1, 2, 3]
test_sizes = [0.3, 0.4, 0.5]
max_epochs = 10

# Prepare data
X = wine_df.drop(columns=['target'])  # Features
y = wine_df['target']  # Target

# Create an Excel workbook to store the results
workbook = xlsxwriter.Workbook('/path/to/KNN_Results.xlsx')  # Update with the actual file path
worksheet = workbook.add_worksheet()

# Header for the Excel file
worksheet.write(0, 0, "k")
worksheet.write(0, 1, "Test Size")
worksheet.write(0, 2, "Epoch")
worksheet.write(0, 3, "Accuracy")
worksheet.write(0, 4, "Precision")
worksheet.write(0, 5, "Recall")
worksheet.write(0, 6, "F1-Score")

row = 1

for k in k_values:
    for test_size in test_sizes:
        for epoch in range(1, max_epochs + 1):
            # Split the data
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=epoch)
            
            # Initialize and train the KNN model
            knn = KNeighborsClassifier(n_neighbors=k)
            knn.fit(X_train, y_train)
            
            # Make predictions
            y_pred = knn.predict(X_test)
            
            # Evaluate the model
            accuracy = knn.score(X_test, y_test)
            report = classification_report(y_test, y_pred, output_dict=True)
            
            # Write results to Excel
            worksheet.write(row, 0, k)
            worksheet.write(row, 1, test_size)
            worksheet.write(row, 2, epoch)
            worksheet.write(row, 3, accuracy)
            worksheet.write(row, 4, report['weighted avg']['precision'])
            worksheet.write(row, 5, report['weighted avg']['recall'])
            worksheet.write(row, 6, report['weighted avg']['f1-score'])
            
            row += 1

            # Display classification report and confusion matrix
            print(f"\nK: {k}, Test Size: {test_size}, Epoch: {epoch}")
            print("Classification Report:")
            print(classification_report(y_test, y_pred))
            print("Confusion Matrix:")
            print(confusion_matrix(y_test, y_pred))

# Close the Excel workbook
workbook.close()
# Out:
# K: 1, Test Size: 0.3, Epoch: 1
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        23
#            1       0.64      0.74      0.68        19
#            2       0.50      0.42      0.45        12
#
#     accuracy                           0.74        54
#    macro avg       0.70      0.69      0.69        54
# weighted avg       0.74      0.74      0.74        54
#
# Confusion Matrix:
# [[21  1  1]
#  [ 1 14  4]
#  [ 0  7  5]]
#
# K: 1, Test Size: 0.3, Epoch: 2
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82        20
#            1       0.65      0.85      0.74        20
#            2       0.56      0.36      0.43        14
#
#     accuracy                           0.70        54
#    macro avg       0.68      0.67      0.66        54
# weighted avg       0.70      0.70      0.69        54
#
# Confusion Matrix:
# [[16  2  2]
#  [ 1 17  2]
#  [ 2  7  5]]
#
# K: 1, Test Size: 0.3, Epoch: 3
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82        23
#            1       0.67      0.42      0.52        19
#            2       0.38      0.50      0.43        12
#
#     accuracy                           0.63        54
#    macro avg       0.60      0.60      0.59        54
# weighted avg       0.65      0.63      0.62        54
#
# Confusion Matrix:
# [[20  1  2]
#  [ 3  8  8]
#  [ 3  3  6]]
#
# K: 1, Test Size: 0.3, Epoch: 4
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86        18
#            1       0.80      0.84      0.82        19
#            2       0.71      0.71      0.71        17
#
#     accuracy                           0.80        54
#    macro avg       0.80      0.79      0.79        54
# weighted avg       0.80      0.80      0.80        54
#
# Confusion Matrix:
# [[15  0  3]
#  [ 1 16  2]
#  [ 1  4 12]]
#
# K: 1, Test Size: 0.3, Epoch: 5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84        23
#            1       0.71      0.83      0.77        18
#            2       0.62      0.62      0.62        13
#
#     accuracy                           0.76        54
#    macro avg       0.74      0.74      0.74        54
# weighted avg       0.77      0.76      0.76        54
#
# Confusion Matrix:
# [[18  2  3]
#  [ 1 15  2]
#  [ 1  4  8]]
#
# K: 1, Test Size: 0.3, Epoch: 6
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92        19
#            1       0.80      0.73      0.76        22
#            2       0.56      0.69      0.62        13
#
#     accuracy                           0.78        54
#    macro avg       0.77      0.77      0.77        54
# weighted avg       0.79      0.78      0.78        54
#
# Confusion Matrix:
# [[17  1  1]
#  [ 0 16  6]
#  [ 1  3  9]]
#
# K: 1, Test Size: 0.3, Epoch: 7
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.92      0.80        13
#            1       0.70      0.88      0.78        24
#            2       0.71      0.29      0.42        17
#
#     accuracy                           0.70        54
#    macro avg       0.71      0.70      0.66        54
# weighted avg       0.71      0.70      0.67        54
#
# Confusion Matrix:
# [[12  0  1]
#  [ 2 21  1]
#  [ 3  9  5]]
#
# K: 1, Test Size: 0.3, Epoch: 8
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84        15
#            1       0.72      0.91      0.81        23
#            2       0.78      0.44      0.56        16
#
#     accuracy                           0.76        54
#    macro avg       0.77      0.74      0.74        54
# weighted avg       0.76      0.76      0.74        54
#
# Confusion Matrix:
# [[13  1  1]
#  [ 1 21  1]
#  [ 2  7  7]]
#
# K: 1, Test Size: 0.3, Epoch: 9
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        25
#            1       0.73      0.73      0.73        15
#            2       0.69      0.64      0.67        14
#
#     accuracy                           0.80        54
#    macro avg       0.77      0.77      0.77        54
# weighted avg       0.79      0.80      0.79        54
#
# Confusion Matrix:
# [[23  0  2]
#  [ 2 11  2]
#  [ 1  4  9]]
#
# K: 1, Test Size: 0.3, Epoch: 10
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76        15
#            1       0.79      0.70      0.75        27
#            2       0.44      0.58      0.50        12
#
#     accuracy                           0.69        54
#    macro avg       0.67      0.67      0.67        54
# weighted avg       0.71      0.69      0.69        54
#
# Confusion Matrix:
# [[11  0  4]
#  [ 3 19  5]
#  [ 0  5  7]]
#
# K: 1, Test Size: 0.4, Epoch: 1
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83        28
#            1       0.58      0.78      0.67        27
#            2       0.55      0.35      0.43        17
#
#     accuracy                           0.68        72
#    macro avg       0.67      0.64      0.64        72
# weighted avg       0.69      0.68      0.67        72
#
# Confusion Matrix:
# [[22  5  1]
#  [ 2 21  4]
#  [ 1 10  6]]
#
# K: 1, Test Size: 0.4, Epoch: 2
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79        25
#            1       0.64      0.84      0.72        25
#            2       0.69      0.50      0.58        22
#
#     accuracy                           0.71        72
#    macro avg       0.72      0.70      0.70        72
# weighted avg       0.72      0.71      0.70        72
#
# Confusion Matrix:
# [[19  4  2]
#  [ 1 21  3]
#  [ 3  8 11]]
#
# K: 1, Test Size: 0.4, Epoch: 3
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85        28
#            1       0.64      0.54      0.58        26
#            2       0.47      0.50      0.49        18
#
#     accuracy                           0.67        72
#    macro avg       0.64      0.64      0.64        72
# weighted avg       0.66      0.67      0.66        72
#
# Confusion Matrix:
# [[25  2  1]
#  [ 3 14  9]
#  [ 3  6  9]]
#
# K: 1, Test Size: 0.4, Epoch: 4
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88        22
#            1       0.73      0.76      0.75        29
#            2       0.57      0.57      0.57        21
#
#     accuracy                           0.74        72
#    macro avg       0.74      0.73      0.73        72
# weighted avg       0.74      0.74      0.74        72
#
# Confusion Matrix:
# [[19  0  3]
#  [ 1 22  6]
#  [ 1  8 12]]
#
# K: 1, Test Size: 0.4, Epoch: 5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85        28
#            1       0.64      0.72      0.68        25
#            2       0.55      0.58      0.56        19
#
#     accuracy                           0.71        72
#    macro avg       0.70      0.69      0.70        72
# weighted avg       0.72      0.71      0.71        72
#
# Confusion Matrix:
# [[22  3  3]
#  [ 1 18  6]
#  [ 1  7 11]]
#
# K: 1, Test Size: 0.4, Epoch: 6
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92        27
#            1       0.81      0.68      0.74        31
#            2       0.48      0.71      0.57        14
#
#     accuracy                           0.76        72
#    macro avg       0.75      0.76      0.74        72
# weighted avg       0.80      0.76      0.77        72
#
# Confusion Matrix:
# [[24  2  1]
#  [ 0 21 10]
#  [ 1  3 10]]
#
# K: 1, Test Size: 0.4, Epoch: 7
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.95      0.80        19
#            1       0.70      0.72      0.71        32
#            2       0.62      0.38      0.47        21
#
#     accuracy                           0.68        72
#    macro avg       0.67      0.68      0.66        72
# weighted avg       0.67      0.68      0.66        72
#
# Confusion Matrix:
# [[18  0  1]
#  [ 5 23  4]
#  [ 3 10  8]]
#
# K: 1, Test Size: 0.4, Epoch: 8
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87        26
#            1       0.78      0.89      0.83        28
#            2       0.82      0.50      0.62        18
#
#     accuracy                           0.81        72
#    macro avg       0.81      0.77      0.78        72
# weighted avg       0.81      0.81      0.79        72
#
# Confusion Matrix:
# [[24  1  1]
#  [ 2 25  1]
#  [ 3  6  9]]
#
# K: 1, Test Size: 0.4, Epoch: 9
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        30
#            1       0.65      0.71      0.68        24
#            2       0.56      0.50      0.53        18
#
#     accuracy                           0.69        72
#    macro avg       0.67      0.67      0.67        72
# weighted avg       0.69      0.69      0.69        72
#
# Confusion Matrix:
# [[24  2  4]
#  [ 4 17  3]
#  [ 2  7  9]]
#
# K: 1, Test Size: 0.4, Epoch: 10
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77        20
#            1       0.81      0.76      0.78        33
#            2       0.64      0.74      0.68        19
#
#     accuracy                           0.75        72
#    macro avg       0.74      0.75      0.74        72
# weighted avg       0.76      0.75      0.75        72
#
# Confusion Matrix:
# [[15  1  4]
#  [ 4 25  4]
#  [ 0  5 14]]
#
# K: 1, Test Size: 0.5, Epoch: 1
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81        33
#            1       0.64      0.79      0.71        34
#            2       0.56      0.41      0.47        22
#
#     accuracy                           0.70        89
#    macro avg       0.68      0.66      0.67        89
# weighted avg       0.70      0.70      0.69        89
#
# Confusion Matrix:
# [[26  5  2]
#  [ 2 27  5]
#  [ 3 10  9]]
#
# K: 1, Test Size: 0.5, Epoch: 2
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.81        28
#            1       0.63      0.84      0.72        31
#            2       0.73      0.53      0.62        30
#
#     accuracy                           0.72        89
#    macro avg       0.74      0.72      0.72        89
# weighted avg       0.73      0.72      0.72        89
#
# Confusion Matrix:
# [[22  4  2]
#  [ 1 26  4]
#  [ 3 11 16]]
#
# K: 1, Test Size: 0.5, Epoch: 3
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87        34
#            1       0.72      0.64      0.68        33
#            2       0.52      0.64      0.57        22
#
#     accuracy                           0.72        89
#    macro avg       0.71      0.71      0.70        89
# weighted avg       0.73      0.72      0.72        89
#
# Confusion Matrix:
# [[29  1  4]
#  [ 3 21  9]
#  [ 1  7 14]]
#
# K: 1, Test Size: 0.5, Epoch: 4
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91        29
#            1       0.81      0.85      0.83        34
#            2       0.72      0.69      0.71        26
#
#     accuracy                           0.82        89
#    macro avg       0.82      0.81      0.82        89
# weighted avg       0.82      0.82      0.82        89
#
# Confusion Matrix:
# [[26  0  3]
#  [ 1 29  4]
#  [ 1  7 18]]
#
# K: 1, Test Size: 0.5, Epoch: 5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.76      0.84        34
#            1       0.63      0.71      0.67        31
#            2       0.50      0.54      0.52        24
#
#     accuracy                           0.69        89
#    macro avg       0.69      0.67      0.68        89
# weighted avg       0.71      0.69      0.69        89
#
# Confusion Matrix:
# [[26  3  5]
#  [ 1 22  8]
#  [ 1 10 13]]
#
# K: 1, Test Size: 0.5, Epoch: 6
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        33
#            1       0.81      0.66      0.72        38
#            2       0.52      0.72      0.60        18
#
#     accuracy                           0.76        89
#    macro avg       0.75      0.76      0.75        89
# weighted avg       0.79      0.76      0.77        89
#
# Confusion Matrix:
# [[30  2  1]
#  [ 2 25 11]
#  [ 1  4 13]]
#
# K: 1, Test Size: 0.5, Epoch: 7
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.96      0.84        24
#            1       0.69      0.66      0.68        41
#            2       0.47      0.38      0.42        24
#
#     accuracy                           0.66        89
#    macro avg       0.64      0.66      0.64        89
# weighted avg       0.65      0.66      0.65        89
#
# Confusion Matrix:
# [[23  0  1]
#  [ 5 27  9]
#  [ 3 12  9]]
#
# K: 1, Test Size: 0.5, Epoch: 8
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89        30
#            1       0.68      0.83      0.75        36
#            2       0.64      0.39      0.49        23
#
#     accuracy                           0.74        89
#    macro avg       0.73      0.71      0.71        89
# weighted avg       0.74      0.74      0.73        89
#
# Confusion Matrix:
# [[27  2  1]
#  [ 2 30  4]
#  [ 2 12  9]]
#
# K: 1, Test Size: 0.5, Epoch: 9
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80        33
#            1       0.61      0.73      0.67        30
#            2       0.62      0.38      0.48        26
#
#     accuracy                           0.67        89
#    macro avg       0.66      0.66      0.65        89
# weighted avg       0.67      0.67      0.66        89
#
# Confusion Matrix:
# [[28  2  3]
#  [ 5 22  3]
#  [ 4 12 10]]
#
# K: 1, Test Size: 0.5, Epoch: 10
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.72      0.78        29
#            1       0.70      0.80      0.75        35
#            2       0.67      0.64      0.65        25
#
#     accuracy                           0.73        89
#    macro avg       0.74      0.72      0.73        89
# weighted avg       0.74      0.73      0.73        89
#
# Confusion Matrix:
# [[21  3  5]
#  [ 4 28  3]
#  [ 0  9 16]]
#
# K: 2, Test Size: 0.3, Epoch: 1
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89        23
#            1       0.56      0.79      0.65        19
#            2       0.00      0.00      0.00        12
#
#     accuracy                           0.67        54
#    macro avg       0.48      0.57      0.52        54
# weighted avg       0.57      0.67      0.61        54
#
# Confusion Matrix:
# [[21  1  1]
#  [ 2 15  2]
#  [ 1 11  0]]
#
# K: 2, Test Size: 0.3, Epoch: 2
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.84        20
#            1       0.67      0.80      0.73        20
#            2       0.60      0.21      0.32        14
#
#     accuracy                           0.70        54
#    macro avg       0.68      0.65      0.63        54
# weighted avg       0.68      0.70      0.66        54
#
# Confusion Matrix:
# [[19  0  1]
#  [ 3 16  1]
#  [ 3  8  3]]
#
# K: 2, Test Size: 0.3, Epoch: 3
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.91      0.82        23
#            1       0.55      0.58      0.56        19
#            2       0.00      0.00      0.00        12
#
#     accuracy                           0.59        54
#    macro avg       0.43      0.50      0.46        54
# weighted avg       0.51      0.59      0.55        54
#
# Confusion Matrix:
# [[21  1  1]
#  [ 3 11  5]
#  [ 4  8  0]]
#
# K: 2, Test Size: 0.3, Epoch: 4
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77        18
#            1       0.59      0.84      0.70        19
#            2       0.33      0.12      0.17        17
#
#     accuracy                           0.61        54
#    macro avg       0.55      0.60      0.55        54
# weighted avg       0.55      0.61      0.56        54
#
# Confusion Matrix:
# [[15  0  3]
#  [ 2 16  1]
#  [ 4 11  2]]
#
# K: 2, Test Size: 0.3, Epoch: 5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84        23
#            1       0.61      0.78      0.68        18
#            2       0.44      0.31      0.36        13
#
#     accuracy                           0.69        54
#    macro avg       0.64      0.64      0.63        54
# weighted avg       0.68      0.69      0.67        54
#
# Confusion Matrix:
# [[19  1  3]
#  [ 2 14  2]
#  [ 1  8  4]]
#
# K: 2, Test Size: 0.3, Epoch: 6
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89        19
#            1       0.70      0.73      0.71        22
#            2       0.50      0.46      0.48        13
#
#     accuracy                           0.72        54
#    macro avg       0.70      0.69      0.70        54
# weighted avg       0.72      0.72      0.72        54
#
# Confusion Matrix:
# [[17  1  1]
#  [ 1 16  5]
#  [ 1  6  6]]
#
# K: 2, Test Size: 0.3, Epoch: 7
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.92      0.71        13
#            1       0.62      0.75      0.68        24
#            2       0.50      0.12      0.19        17
#
#     accuracy                           0.59        54
#    macro avg       0.56      0.60      0.53        54
# weighted avg       0.57      0.59      0.53        54
#
# Confusion Matrix:
# [[12  0  1]
#  [ 5 18  1]
#  [ 4 11  2]]
#
# K: 2, Test Size: 0.3, Epoch: 8
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.93      0.82        15
#            1       0.69      0.96      0.80        23
#            2       1.00      0.19      0.32        16
#
#     accuracy                           0.72        54
#    macro avg       0.81      0.69      0.65        54
# weighted avg       0.79      0.72      0.66        54
#
# Confusion Matrix:
# [[14  1  0]
#  [ 1 22  0]
#  [ 4  9  3]]
#
# K: 2, Test Size: 0.3, Epoch: 9
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91        25
#            1       0.61      0.73      0.67        15
#            2       0.62      0.36      0.45        14
#
#     accuracy                           0.74        54
#    macro avg       0.70      0.68      0.68        54
# weighted avg       0.73      0.74      0.72        54
#
# Confusion Matrix:
# [[24  0  1]
#  [ 2 11  2]
#  [ 2  7  5]]
#
# K: 2, Test Size: 0.3, Epoch: 10
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.80      0.71        15
#            1       0.68      0.78      0.72        27
#            2       0.25      0.08      0.12        12
#
#     accuracy                           0.63        54
#    macro avg       0.52      0.55      0.52        54
# weighted avg       0.57      0.63      0.59        54
#
# Confusion Matrix:
# [[12  1  2]
#  [ 5 21  1]
#  [ 2  9  1]]
#
# K: 2, Test Size: 0.4, Epoch: 1
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80        28
#            1       0.54      0.81      0.65        27
#            2       0.25      0.06      0.10        17
#
#     accuracy                           0.62        72
#    macro avg       0.53      0.55      0.51        72
# weighted avg       0.58      0.62      0.58        72
#
# Confusion Matrix:
# [[22  5  1]
#  [ 3 22  2]
#  [ 2 14  1]]
#
# K: 2, Test Size: 0.4, Epoch: 2
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77        25
#            1       0.53      0.80      0.63        25
#            2       0.57      0.18      0.28        22
#
#     accuracy                           0.61        72
#    macro avg       0.61      0.59      0.56        72
# weighted avg       0.61      0.61      0.57        72
#
# Confusion Matrix:
# [[20  4  1]
#  [ 3 20  2]
#  [ 4 14  4]]
#
# K: 2, Test Size: 0.4, Epoch: 3
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85        28
#            1       0.56      0.73      0.63        26
#            2       0.29      0.11      0.16        18
#
#     accuracy                           0.64        72
#    macro avg       0.55      0.58      0.55        72
# weighted avg       0.59      0.64      0.60        72
#
# Confusion Matrix:
# [[25  2  1]
#  [ 3 19  4]
#  [ 3 13  2]]
#
# K: 2, Test Size: 0.4, Epoch: 4
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81        22
#            1       0.70      0.90      0.79        29
#            2       0.60      0.29      0.39        21
#
#     accuracy                           0.71        72
#    macro avg       0.69      0.68      0.66        72
# weighted avg       0.69      0.71      0.68        72
#
# Confusion Matrix:
# [[19  0  3]
#  [ 2 26  1]
#  [ 4 11  6]]
#
# K: 2, Test Size: 0.4, Epoch: 5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85        28
#            1       0.50      0.68      0.58        25
#            2       0.33      0.21      0.26        19
#
#     accuracy                           0.61        72
#    macro avg       0.57      0.57      0.56        72
# weighted avg       0.61      0.61      0.60        72
#
# Confusion Matrix:
# [[23  3  2]
#  [ 2 17  6]
#  [ 1 14  4]]
#
# K: 2, Test Size: 0.4, Epoch: 6
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        27
#            1       0.74      0.74      0.74        31
#            2       0.43      0.43      0.43        14
#
#     accuracy                           0.75        72
#    macro avg       0.70      0.70      0.70        72
# weighted avg       0.75      0.75      0.75        72
#
# Confusion Matrix:
# [[25  1  1]
#  [ 1 23  7]
#  [ 1  7  6]]
#
# K: 2, Test Size: 0.4, Epoch: 7
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.95      0.72        19
#            1       0.67      0.69      0.68        32
#            2       0.38      0.14      0.21        21
#
#     accuracy                           0.60        72
#    macro avg       0.54      0.59      0.53        72
# weighted avg       0.56      0.60      0.55        72
#
# Confusion Matrix:
# [[18  0  1]
#  [ 6 22  4]
#  [ 7 11  3]]
#
# K: 2, Test Size: 0.4, Epoch: 8
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.96      0.88        26
#            1       0.70      0.93      0.80        28
#            2       1.00      0.22      0.36        18
#
#     accuracy                           0.76        72
#    macro avg       0.84      0.70      0.68        72
# weighted avg       0.81      0.76      0.72        72
#
# Confusion Matrix:
# [[25  1  0]
#  [ 2 26  0]
#  [ 4 10  4]]
#
# K: 2, Test Size: 0.4, Epoch: 9
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86        30
#            1       0.61      0.71      0.65        24
#            2       0.56      0.28      0.37        18
#
#     accuracy                           0.69        72
#    macro avg       0.65      0.64      0.63        72
# weighted avg       0.67      0.69      0.67        72
#
# Confusion Matrix:
# [[28  1  1]
#  [ 4 17  3]
#  [ 3 10  5]]
#
# K: 2, Test Size: 0.4, Epoch: 10
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.95      0.78        20
#            1       0.69      0.82      0.75        33
#            2       0.75      0.16      0.26        19
#
#     accuracy                           0.68        72
#    macro avg       0.70      0.64      0.60        72
# weighted avg       0.70      0.68      0.63        72
#
# Confusion Matrix:
# [[19  1  0]
#  [ 5 27  1]
#  [ 5 11  3]]
#
# K: 2, Test Size: 0.5, Epoch: 1
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        33
#            1       0.58      0.85      0.69        34
#            2       0.33      0.09      0.14        22
#
#     accuracy                           0.64        89
#    macro avg       0.57      0.58      0.54        89
# weighted avg       0.60      0.64      0.59        89
#
# Confusion Matrix:
# [[26  5  2]
#  [ 3 29  2]
#  [ 4 16  2]]
#
# K: 2, Test Size: 0.5, Epoch: 2
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78        28
#            1       0.53      0.81      0.64        31
#            2       0.64      0.23      0.34        30
#
#     accuracy                           0.62        89
#    macro avg       0.64      0.62      0.59        89
# weighted avg       0.63      0.62      0.58        89
#
# Confusion Matrix:
# [[23  4  1]
#  [ 3 25  3]
#  [ 5 18  7]]
#
# K: 2, Test Size: 0.5, Epoch: 3
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.86        34
#            1       0.67      0.79      0.72        33
#            2       0.50      0.23      0.31        22
#
#     accuracy                           0.71        89
#    macro avg       0.66      0.65      0.63        89
# weighted avg       0.68      0.71      0.68        89
#
# Confusion Matrix:
# [[32  1  1]
#  [ 3 26  4]
#  [ 5 12  5]]
#
# K: 2, Test Size: 0.5, Epoch: 4
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85        29
#            1       0.63      0.94      0.75        34
#            2       0.50      0.12      0.19        26
#
#     accuracy                           0.69        89
#    macro avg       0.65      0.65      0.60        89
# weighted avg       0.65      0.69      0.62        89
#
# Confusion Matrix:
# [[26  0  3]
#  [ 2 32  0]
#  [ 4 19  3]]
#
# K: 2, Test Size: 0.5, Epoch: 5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81        34
#            1       0.50      0.71      0.59        31
#            2       0.40      0.25      0.31        24
#
#     accuracy                           0.61        89
#    macro avg       0.59      0.57      0.57        89
# weighted avg       0.61      0.61      0.60        89
#
# Confusion Matrix:
# [[26  5  3]
#  [ 3 22  6]
#  [ 1 17  6]]
#
# K: 2, Test Size: 0.5, Epoch: 6
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88        33
#            1       0.70      0.74      0.72        38
#            2       0.43      0.33      0.38        18
#
#     accuracy                           0.72        89
#    macro avg       0.66      0.66      0.66        89
# weighted avg       0.70      0.72      0.71        89
#
# Confusion Matrix:
# [[30  2  1]
#  [ 3 28  7]
#  [ 2 10  6]]
#
# K: 2, Test Size: 0.5, Epoch: 7
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.96      0.72        24
#            1       0.68      0.63      0.66        41
#            2       0.36      0.17      0.23        24
#
#     accuracy                           0.60        89
#    macro avg       0.54      0.59      0.54        89
# weighted avg       0.57      0.60      0.56        89
#
# Confusion Matrix:
# [[23  0  1]
#  [ 9 26  6]
#  [ 8 12  4]]
#
# K: 2, Test Size: 0.5, Epoch: 8
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89        30
#            1       0.65      0.92      0.76        36
#            2       0.80      0.17      0.29        23
#
#     accuracy                           0.73        89
#    macro avg       0.77      0.67      0.64        89
# weighted avg       0.75      0.73      0.68        89
#
# Confusion Matrix:
# [[28  2  0]
#  [ 2 33  1]
#  [ 3 16  4]]
#
# K: 2, Test Size: 0.5, Epoch: 9
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.94      0.84        33
#            1       0.55      0.73      0.63        30
#            2       0.50      0.15      0.24        26
#
#     accuracy                           0.64        89
#    macro avg       0.60      0.61      0.57        89
# weighted avg       0.61      0.64      0.59        89
#
# Confusion Matrix:
# [[31  1  1]
#  [ 5 22  3]
#  [ 5 17  4]]
#
# K: 2, Test Size: 0.5, Epoch: 10
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.93      0.82        29
#            1       0.64      0.83      0.72        35
#            2       0.71      0.20      0.31        25
#
#     accuracy                           0.69        89
#    macro avg       0.70      0.65      0.62        89
# weighted avg       0.69      0.69      0.64        89
#
# Confusion Matrix:
# [[27  1  1]
#  [ 5 29  1]
#  [ 5 15  5]]
#
# K: 3, Test Size: 0.3, Epoch: 1
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89        23
#            1       0.72      0.68      0.70        19
#            2       0.50      0.50      0.50        12
#
#     accuracy                           0.74        54
#    macro avg       0.70      0.70      0.70        54
# weighted avg       0.74      0.74      0.74        54
#
# Confusion Matrix:
# [[21  0  2]
#  [ 2 13  4]
#  [ 1  5  6]]
#
# K: 3, Test Size: 0.3, Epoch: 2
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        20
#            1       0.65      0.75      0.70        20
#            2       0.55      0.43      0.48        14
#
#     accuracy                           0.67        54
#    macro avg       0.65      0.64      0.64        54
# weighted avg       0.66      0.67      0.66        54
#
# Confusion Matrix:
# [[15  3  2]
#  [ 2 15  3]
#  [ 3  5  6]]
#
# K: 3, Test Size: 0.3, Epoch: 3
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87        23
#            1       0.56      0.53      0.54        19
#            2       0.31      0.33      0.32        12
#
#     accuracy                           0.63        54
#    macro avg       0.58      0.58      0.58        54
# weighted avg       0.63      0.63      0.63        54
#
# Confusion Matrix:
# [[20  0  3]
#  [ 3 10  6]
#  [ 0  8  4]]
#
# K: 3, Test Size: 0.3, Epoch: 4
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77        18
#            1       0.74      0.74      0.74        19
#            2       0.57      0.47      0.52        17
#
#     accuracy                           0.69        54
#    macro avg       0.67      0.68      0.67        54
# weighted avg       0.68      0.69      0.68        54
#
# Confusion Matrix:
# [[15  0  3]
#  [ 2 14  3]
#  [ 4  5  8]]
#
# K: 3, Test Size: 0.3, Epoch: 5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.74      0.81        23
#            1       0.71      0.67      0.69        18
#            2       0.56      0.77      0.65        13
#
#     accuracy                           0.72        54
#    macro avg       0.72      0.73      0.71        54
# weighted avg       0.75      0.72      0.73        54
#
# Confusion Matrix:
# [[17  2  4]
#  [ 2 12  4]
#  [ 0  3 10]]
#
# K: 3, Test Size: 0.3, Epoch: 6
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89        19
#            1       0.76      0.73      0.74        22
#            2       0.50      0.54      0.52        13
#
#     accuracy                           0.74        54
#    macro avg       0.72      0.72      0.72        54
# weighted avg       0.75      0.74      0.74        54
#
# Confusion Matrix:
# [[17  0  2]
#  [ 1 16  5]
#  [ 1  5  7]]
#
# K: 3, Test Size: 0.3, Epoch: 7
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.92      0.75        13
#            1       0.73      0.79      0.76        24
#            2       0.67      0.35      0.46        17
#
#     accuracy                           0.69        54
#    macro avg       0.68      0.69      0.66        54
# weighted avg       0.69      0.69      0.66        54
#
# Confusion Matrix:
# [[12  0  1]
#  [ 3 19  2]
#  [ 4  7  6]]
#
# K: 3, Test Size: 0.3, Epoch: 8
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79        15
#            1       0.70      0.70      0.70        23
#            2       0.46      0.38      0.41        16
#
#     accuracy                           0.65        54
#    macro avg       0.63      0.65      0.63        54
# weighted avg       0.63      0.65      0.64        54
#
# Confusion Matrix:
# [[13  0  2]
#  [ 2 16  5]
#  [ 3  7  6]]
#
# K: 3, Test Size: 0.3, Epoch: 9
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        25
#            1       0.56      0.60      0.58        15
#            2       0.54      0.50      0.52        14
#
#     accuracy                           0.70        54
#    macro avg       0.66      0.66      0.66        54
# weighted avg       0.70      0.70      0.70        54
#
# Confusion Matrix:
# [[22  1  2]
#  [ 2  9  4]
#  [ 1  6  7]]
#
# K: 3, Test Size: 0.3, Epoch: 10
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.67      0.71        15
#            1       0.89      0.63      0.74        27
#            2       0.45      0.83      0.59        12
#
#     accuracy                           0.69        54
#    macro avg       0.71      0.71      0.68        54
# weighted avg       0.76      0.69      0.70        54
#
# Confusion Matrix:
# [[10  0  5]
#  [ 3 17  7]
#  [ 0  2 10]]
#
# K: 3, Test Size: 0.4, Epoch: 1
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80        28
#            1       0.62      0.74      0.68        27
#            2       0.54      0.41      0.47        17
#
#     accuracy                           0.68        72
#    macro avg       0.66      0.65      0.65        72
# weighted avg       0.68      0.68      0.68        72
#
# Confusion Matrix:
# [[22  4  2]
#  [ 3 20  4]
#  [ 2  8  7]]
#
# K: 3, Test Size: 0.4, Epoch: 2
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76        25
#            1       0.63      0.76      0.69        25
#            2       0.65      0.50      0.56        22
#
#     accuracy                           0.68        72
#    macro avg       0.68      0.67      0.67        72
# weighted avg       0.68      0.68      0.68        72
#
# Confusion Matrix:
# [[19  4  2]
#  [ 2 19  4]
#  [ 4  7 11]]
#
# K: 3, Test Size: 0.4, Epoch: 3
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        28
#            1       0.58      0.58      0.58        26
#            2       0.39      0.39      0.39        18
#
#     accuracy                           0.64        72
#    macro avg       0.61      0.61      0.61        72
# weighted avg       0.64      0.64      0.64        72
#
# Confusion Matrix:
# [[24  1  3]
#  [ 3 15  8]
#  [ 1 10  7]]
#
# K: 3, Test Size: 0.4, Epoch: 4
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81        22
#            1       0.83      0.69      0.75        29
#            2       0.57      0.62      0.59        21
#
#     accuracy                           0.72        72
#    macro avg       0.72      0.72      0.72        72
# weighted avg       0.73      0.72      0.72        72
#
# Confusion Matrix:
# [[19  0  3]
#  [ 2 20  7]
#  [ 4  4 13]]
#
# K: 3, Test Size: 0.4, Epoch: 5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85        28
#            1       0.64      0.56      0.60        25
#            2       0.54      0.74      0.62        19
#
#     accuracy                           0.69        72
#    macro avg       0.70      0.69      0.69        72
# weighted avg       0.72      0.69      0.70        72
#
# Confusion Matrix:
# [[22  3  3]
#  [ 2 14  9]
#  [ 0  5 14]]
#
# K: 3, Test Size: 0.4, Epoch: 6
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89        27
#            1       0.79      0.74      0.77        31
#            2       0.50      0.57      0.53        14
#
#     accuracy                           0.76        72
#    macro avg       0.73      0.73      0.73        72
# weighted avg       0.77      0.76      0.77        72
#
# Confusion Matrix:
# [[24  2  1]
#  [ 1 23  7]
#  [ 2  4  8]]
#
# K: 3, Test Size: 0.4, Epoch: 7
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.95      0.69        19
#            1       0.77      0.62      0.69        32
#            2       0.54      0.33      0.41        21
#
#     accuracy                           0.62        72
#    macro avg       0.62      0.64      0.60        72
# weighted avg       0.64      0.62      0.61        72
#
# Confusion Matrix:
# [[18  0  1]
#  [ 7 20  5]
#  [ 8  6  7]]
#
# K: 3, Test Size: 0.4, Epoch: 8
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.86        26
#            1       0.70      0.68      0.69        28
#            2       0.47      0.39      0.42        18
#
#     accuracy                           0.69        72
#    macro avg       0.66      0.66      0.66        72
# weighted avg       0.68      0.69      0.68        72
#
# Confusion Matrix:
# [[24  0  2]
#  [ 3 19  6]
#  [ 3  8  7]]
#
# K: 3, Test Size: 0.4, Epoch: 9
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78        30
#            1       0.58      0.58      0.58        24
#            2       0.42      0.44      0.43        18
#
#     accuracy                           0.62        72
#    macro avg       0.60      0.60      0.60        72
# weighted avg       0.63      0.62      0.63        72
#
# Confusion Matrix:
# [[23  3  4]
#  [ 3 14  7]
#  [ 3  7  8]]
#
# K: 3, Test Size: 0.4, Epoch: 10
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.77        20
#            1       0.87      0.61      0.71        33
#            2       0.52      0.68      0.59        19
#
#     accuracy                           0.69        72
#    macro avg       0.70      0.71      0.69        72
# weighted avg       0.73      0.69      0.70        72
#
# Confusion Matrix:
# [[17  0  3]
#  [ 4 20  9]
#  [ 3  3 13]]
#
# K: 3, Test Size: 0.5, Epoch: 1
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81        33
#            1       0.74      0.74      0.74        34
#            2       0.46      0.50      0.48        22
#
#     accuracy                           0.70        89
#    macro avg       0.68      0.67      0.68        89
# weighted avg       0.71      0.70      0.70        89
#
# Confusion Matrix:
# [[26  0  7]
#  [ 3 25  6]
#  [ 2  9 11]]
#
# K: 3, Test Size: 0.5, Epoch: 2
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.77        28
#            1       0.60      0.77      0.68        31
#            2       0.65      0.43      0.52        30
#
#     accuracy                           0.66        89
#    macro avg       0.67      0.66      0.66        89
# weighted avg       0.67      0.66      0.65        89
#
# Confusion Matrix:
# [[22  4  2]
#  [ 2 24  5]
#  [ 5 12 13]]
#
# K: 3, Test Size: 0.5, Epoch: 3
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.86        34
#            1       0.70      0.58      0.63        33
#            2       0.41      0.41      0.41        22
#
#     accuracy                           0.67        89
#    macro avg       0.64      0.64      0.64        89
# weighted avg       0.67      0.67      0.67        89
#
# Confusion Matrix:
# [[32  0  2]
#  [ 3 19 11]
#  [ 5  8  9]]
#
# K: 3, Test Size: 0.5, Epoch: 4
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85        29
#            1       0.70      0.76      0.73        34
#            2       0.55      0.42      0.48        26
#
#     accuracy                           0.71        89
#    macro avg       0.69      0.69      0.69        89
# weighted avg       0.69      0.71      0.70        89
#
# Confusion Matrix:
# [[26  0  3]
#  [ 2 26  6]
#  [ 4 11 11]]
#
# K: 3, Test Size: 0.5, Epoch: 5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.71      0.81        34
#            1       0.57      0.65      0.61        31
#            2       0.45      0.54      0.49        24
#
#     accuracy                           0.64        89
#    macro avg       0.66      0.63      0.64        89
# weighted avg       0.69      0.64      0.65        89
#
# Confusion Matrix:
# [[24  4  6]
#  [ 1 20 10]
#  [ 0 11 13]]
#
# K: 3, Test Size: 0.5, Epoch: 6
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.86        33
#            1       0.72      0.68      0.70        38
#            2       0.38      0.33      0.35        18
#
#     accuracy                           0.70        89
#    macro avg       0.64      0.64      0.64        89
# weighted avg       0.68      0.70      0.69        89
#
# Confusion Matrix:
# [[30  2  1]
#  [ 3 26  9]
#  [ 4  8  6]]
#
# K: 3, Test Size: 0.5, Epoch: 7
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83        24
#            1       0.76      0.61      0.68        41
#            2       0.41      0.46      0.43        24
#
#     accuracy                           0.65        89
#    macro avg       0.64      0.66      0.65        89
# weighted avg       0.66      0.65      0.65        89
#
# Confusion Matrix:
# [[22  0  2]
#  [ 2 25 14]
#  [ 5  8 11]]
#
# K: 3, Test Size: 0.5, Epoch: 8
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89        30
#            1       0.72      0.72      0.72        36
#            2       0.59      0.57      0.58        23
#
#     accuracy                           0.74        89
#    macro avg       0.73      0.73      0.73        89
# weighted avg       0.74      0.74      0.74        89
#
# Confusion Matrix:
# [[27  1  2]
#  [ 3 26  7]
#  [ 1  9 13]]
#
# K: 3, Test Size: 0.5, Epoch: 9
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82        33
#            1       0.61      0.63      0.62        30
#            2       0.45      0.35      0.39        26
#
#     accuracy                           0.64        89
#    macro avg       0.61      0.62      0.61        89
# weighted avg       0.62      0.64      0.63        89
#
# Confusion Matrix:
# [[29  0  4]
#  [ 4 19  7]
#  [ 5 12  9]]
#
# K: 3, Test Size: 0.5, Epoch: 10
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87        29
#            1       0.72      0.66      0.69        35
#            2       0.58      0.60      0.59        25
#
#     accuracy                           0.72        89
#    macro avg       0.71      0.72      0.71        89
# weighted avg       0.72      0.72      0.72        89
#
# Confusion Matrix:
# [[26  0  3]
#  [ 4 23  8]
#  [ 1  9 15]]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\dharm\AppData\Local\Programs\Python\Python312\Lib\site-packages\xlsxwriter\workbook.py:352, in Workbook.close(self)
#     351 try:
# --> 352     self._store_workbook()
#     353 except IOError as e:
#
# File c:\Users\dharm\AppData\Local\Programs\Python\Python312\Lib\site-packages\xlsxwriter\workbook.py:697, in Workbook._store_workbook(self)
#     696 except IOError as e:
# --> 697     raise e
#     699 # Assemble worksheets into a workbook.
#
# File c:\Users\dharm\AppData\Local\Programs\Python\Python312\Lib\site-packages\xlsxwriter\workbook.py:690, in Workbook._store_workbook(self)
#     689 try:
# --> 690     xlsx_file = ZipFile(
#     691         self.filename,
#     692         "w",
#     693         compression=ZIP_DEFLATED,
#     694         allowZip64=self.allow_zip64,
#     695     )
#     696 except IOError as e:
#
# File c:\Users\dharm\AppData\Local\Programs\Python\Python312\Lib\zipfile\__init__.py:1331, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1330 try:
# -> 1331     self.fp = io.open(file, filemode)
#    1332 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/path/to/KNN_Results.xlsx'
#
# During handling of the above exception, another exception occurred:
#
# FileCreateError                           Traceback (most recent call last)
# Cell In[4], line 66
#      63             print(confusion_matrix(y_test, y_pred))
#      65 # Close the Excel workbook
# ---> 66 workbook.close()
#
# File c:\Users\dharm\AppData\Local\Programs\Python\Python312\Lib\site-packages\xlsxwriter\workbook.py:354, in Workbook.close(self)
#     352     self._store_workbook()
#     353 except IOError as e:
# --> 354     raise FileCreateError(e)
#     355 except LargeZipFile:
#     356     raise FileSizeError(
#     357         "Filesize would require ZIP64 extensions. "
#     358         "Use workbook.use_zip64()."
#     359     )
#
# FileCreateError: [Errno 2] No such file or directory: '/path/to/KNN_Results.xlsx'

# %%
pip install xlsxwriter
# Out:
# Collecting xlsxwriterNote: you may need to restart the kernel to use updated packages.
#
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.2.0
